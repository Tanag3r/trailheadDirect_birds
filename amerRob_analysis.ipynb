# %%
import sys
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import h5py
sys.path.append('../')

# %%
redTown = pd.read_csv('L6226117_data2020_2021.csv', sep= ",")

# %%
redTown.head(5)
# Out:
#    Unnamed: 0 speciesCode                 comName                sciName  \
# 0           0      rebsap  Red-breasted Sapsucker      Sphyrapicus ruber
# 1           1      amecro           American Crow  Corvus brachyrhynchos
# 2           2     pacwre1            Pacific Wren  Troglodytes pacificus
# 3           3      sonspa            Song Sparrow      Melospiza melodia
# 4           4      wlswar        Wilson's Warbler     Cardellina pusilla
#
#       locId              locName                obsDt  howMany        lat  \
# 0  L6226117  Red Town Trail Head  2020-05-29 10:30:00      1.0  47.534588
# 1  L6226117  Red Town Trail Head  2020-05-29 10:30:00      2.0  47.534588
# 2  L6226117  Red Town Trail Head  2020-05-29 10:30:00      1.0  47.534588
# 3  L6226117  Red Town Trail Head  2020-05-29 10:30:00      6.0  47.534588
# 4  L6226117  Red Town Trail Head  2020-05-29 10:30:00      1.0  47.534588
#
#           lng  obsValid  obsReviewed  locationPrivate      subId
# ...

# %%
redTown.groupby('comName').sum()['howMany']
# Out:
# comName
# American Crow                   3.0
# American Goldfinch              6.0
# American Robin                 16.0
# Band-tailed Pigeon              3.0
# Barn Swallow                    2.0
# Barred Owl                      2.0
# Bewick's Wren                   2.0
# Black-capped Chickadee          3.0
# Black-headed Grosbeak           6.0
# Black-throated Gray Warbler     4.0
# Brown Creeper                   8.0
# Brown-headed Cowbird            1.0
# Bushtit                        10.0
# Cassin's Vireo                  1.0
# Cedar Waxwing                   4.0
# Chestnut-backed Chickadee       4.0
# Common Raven                    2.0
# Common Yellowthroat             1.0
# Dark-eyed Junco                10.0
# Downy Woodpecker                1.0
# Golden-crowned Kinglet          2.0
# Hairy Woodpecker                2.0
# Northern Flicker                2.0
# Pacific Wren                   11.0
# Pacific-slope Flycatcher       17.0
# Pileated Woodpecker             2.0
# ...
